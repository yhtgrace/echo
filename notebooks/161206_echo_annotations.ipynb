# %% [markdown]
# Look at how echo annotations vary with variables of interest.

# %%
import numpy as np
import pandas as pd
import psycopg2

import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.style
matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
# create a database connection
sqluser = 'mimic'
dbname = 'mimic'
schema_name = 'mimiciii'

cur = None

# %%
if cur: 
    cur.close()
    con.close()

con = psycopg2.connect(dbname = dbname, user = sqluser)
cur = con.cursor()
cur.execute('SET search_path to ' + schema_name)

# %%
query = \
"""
SELECT * FROM echo_features; 
"""
ef = pd.read_sql_query(query, con)
ef.head()
# Out:
#    row_id  icustay_id  hadm_id  subject_id       age_at_intime gender  height  \
# 0   83481      200003   163557       27513 17625 days 19:50:04      M    70.0
# 1   99984      200009   129607       29904 17353 days 10:34:32      F    64.0
# 2   99985      200009   129607       29904 17353 days 10:34:32      F    63.0
# 3   71333      200014   127229        9514 30921 days 23:16:48      M     NaN
# 4   77556      200019   112486       21789 30249 days 09:03:12      F     NaN
#
#    weight        bmi              ethnicity        ...          \
# 0   160.0  22.955102                  WHITE        ...
# 1   190.0  32.609863                  WHITE        ...
# 2   180.0  31.882086                  WHITE        ...
# 3     NaN        NaN  UNKNOWN/NOT SPECIFIED        ...
# 4     NaN        NaN                  WHITE        ...
#
#   fluid_daily_balance_ml_1  fluid_chartdate_1  fluid_daily_input_ml_2  \
# 0                   -975.0         2199-08-03                     NaN
# 1                   4002.0         2189-12-01                     NaN
# 2                   4002.0         2189-12-01                     NaN
# 3                      NaN               None                     NaN
# 4                    456.0         2178-07-08                  1970.0
#
#    fluid_daily_output_ml_2  fluid_daily_balance_ml_2  fluid_chartdate_2  \
# 0                      NaN                       NaN               None
# 1                      NaN                       NaN               None
# 2                      NaN                       NaN               None
# 3                      NaN                       NaN               None
# 4                    985.0                     985.0         2178-07-09
#
#    fluid_daily_input_ml_3  fluid_daily_output_ml_3  fluid_daily_balance_ml_3  \
# 0                     NaN                      NaN                       NaN
# 1                     NaN                      NaN                       NaN
# 2                     NaN                      NaN                       NaN
# 3                     NaN                      NaN                       NaN
# 4                   620.0                    299.0                     321.0
#
#    fluid_chartdate_3
# 0               None
# 1               None
# 2               None
# 3               None
# 4         2178-07-10
#
# [5 rows x 130 columns]

# %%
ef[['icustay_id', 'ed_chartdate', 'fluid_chartdate_1', 'fluid_daily_input_ml_1', 
    'fluid_chartdate_2', 'fluid_daily_input_ml_2', 
    'fluid_chartdate_3', 'fluid_daily_input_ml_3', 
    'outtime']].head()
# Out:
#    icustay_id ed_chartdate fluid_chartdate_1  fluid_daily_input_ml_1  \
# 0      200003   2199-08-03        2199-08-03                  2687.0
# 1      200009   2189-12-01        2189-12-01                  7900.0
# 2      200009   2189-12-01        2189-12-01                  7900.0
# 3      200014   2105-02-18              None                     NaN
# 4      200019   2178-07-08        2178-07-08                  1400.0
#
#   fluid_chartdate_2  fluid_daily_input_ml_2 fluid_chartdate_3  \
# 0              None                     NaN              None
# 1              None                     NaN              None
# 2              None                     NaN              None
# 3              None                     NaN              None
# 4        2178-07-09                  1970.0        2178-07-10
#
#    fluid_daily_input_ml_3             outtime
# 0                     NaN 2199-08-08 17:09:18
# 1                     NaN 2189-12-02 14:17:37
# 2                     NaN 2189-12-02 14:17:37
# 3                     NaN 2105-02-18 16:53:29
# 4                   620.0 2178-07-11 10:28:40

# %% [markdown]
# ## Demographics
#
# ### Age

# %%
print(ef.shape)
g = sns.boxplot('survived_icustay', 'ea_age', data = ef)
# Out:
# (25512, 130)

# %% [markdown]
# ### Sex

# %%
to_plot = ef[['gender', 'survived_icustay', 'subject_id']].dropna().groupby(['gender', 'survived_icustay'])['subject_id'].count().reset_index()
to_plot.columns = ['gender', 'survived_icustay', 'count']

sns.barplot('survived_icustay', 'count', data = to_plot, hue = 'gender')
to_plot.groupby('gender')['count'].sum()
# Out:
# gender
# F    5222
# M    6085
# Name: count, dtype: int64

# %% [markdown]
# Obvious outliers in some columns:
#
# ### Height

# %%
g = sns.boxplot('survived_icustay', 'height', data = ef)

# %% [markdown]
# ### Weight

# %%
g = sns.boxplot('survived_icustay', 'weight', data = ef)

# %% [markdown]
# ### BMI

# %%
g = sns.boxplot('survived_icustay', 'bmi', data = ef)

# %% [markdown]
# ## Race

# %%
to_plot = ef[['ethnicity', 'survived_icustay', 'subject_id']].dropna().groupby(['ethnicity', 'survived_icustay'])['subject_id'].count().reset_index()
to_plot.columns = ['ethnicity', 'survived_icustay', 'count']

#sns.barplot('ea_lv_systolic', 'count', data = to_plot, hue = 'ethnicity')
to_plot.groupby('ethnicity')['count'].sum()
# Out:
# ethnicity
# AMERICAN INDIAN/ALASKA NATIVE                   7
# ASIAN                                         168
# ASIAN - ASIAN INDIAN                           13
# ASIAN - CAMBODIAN                               2
# ASIAN - CHINESE                                38
# ASIAN - FILIPINO                                7
# ASIAN - JAPANESE                                1
# ASIAN - KOREAN                                  1
# ASIAN - OTHER                                   4
# ASIAN - VIETNAMESE                              6
# BLACK/AFRICAN                                   3
# BLACK/AFRICAN AMERICAN                        864
# BLACK/CAPE VERDEAN                             19
# BLACK/HAITIAN                                   8
# HISPANIC OR LATINO                            221
# HISPANIC/LATINO - CUBAN                        10
# HISPANIC/LATINO - DOMINICAN                     6
# HISPANIC/LATINO - GUATEMALAN                    7
# HISPANIC/LATINO - PUERTO RICAN                 33
# MIDDLE EASTERN                                  5
# MULTI RACE ETHNICITY                           13
# NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER       6
# OTHER                                         168
# PATIENT DECLINED TO ANSWER                     78
# PORTUGUESE                                     15
# UNABLE TO OBTAIN                              221
# UNKNOWN/NOT SPECIFIED                        1199
# WHITE                                        8145
# WHITE - BRAZILIAN                               4
# WHITE - EASTERN EUROPEAN                        2
# WHITE - OTHER EUROPEAN                         11
# WHITE - RUSSIAN                                22
# Name: count, dtype: int64

# %% [markdown]
# ## Filters
#
# ### On vasopressors

# %%
var = 'ps_vaso'

to_plot = ef[[var, 'survived_icustay', 'subject_id']].dropna().groupby([var, 'survived_icustay'])['subject_id'].count().reset_index()
to_plot.columns = [var, 'survived_icustay', 'count']

sns.barplot('survived_icustay', 'count', data = to_plot, hue = var)
to_plot.groupby(var)['count'].sum()
# Out:
# ps_vaso
# False    5963
# True     5344
# Name: count, dtype: int64

# %% [markdown]
# ### Chronic dialysis

# %%
var = 'chronic_dialysis_flg'

to_plot = ef[[var, 'survived_icustay', 'subject_id']].dropna().groupby([var, 'survived_icustay'])['subject_id'].count().reset_index()
to_plot.columns = [var, 'survived_icustay', 'count']

sns.barplot('survived_icustay', 'count', data = to_plot, hue = var)
to_plot.groupby(var)['count'].sum()
# Out:
# chronic_dialysis_flg
# False    10080
# True      1227
# Name: count, dtype: int64

# %% [markdown]
# ### Excluded diagnosis

# %%
var = 'diag_xc'

to_plot = ef[[var, 'survived_icustay', 'subject_id']].dropna().groupby([var, 'survived_icustay'])['subject_id'].count().reset_index()
to_plot.columns = [var, 'survived_icustay', 'count']

sns.barplot('survived_icustay', 'count', data = to_plot, hue = var)
to_plot.groupby(var)['count'].sum()
# Out:
# diag_xc
# False    1864
# True     9443
# Name: count, dtype: int64

# %% [markdown]
# ## Outcomes

# %%
var = 'survived_icustay'

to_plot = ef[[var, 'ea_lv_systolic', 'subject_id']].dropna().groupby([var, 'ea_lv_systolic'])['subject_id'].count().reset_index()
to_plot.columns = [var, 'ea_lv_systolic', 'count']

sns.barplot('ea_lv_systolic', 'count', data = to_plot, hue = var)
to_plot.groupby(var)['count'].sum()
# Out:
# survived_icustay
# False    2277
# True     6041
# Name: count, dtype: int64

# %%
var = 'survived_hadm'

to_plot = ef[[var, 'ea_lv_systolic', 'subject_id']].dropna().groupby([var, 'ea_lv_systolic'])['subject_id'].count().reset_index()
to_plot.columns = [var, 'ea_lv_systolic', 'count']

sns.barplot('ea_lv_systolic', 'count', data = to_plot, hue = var)
to_plot.groupby(var)['count'].sum()
# Out:
# survived_hadm
# False    2739
# True     5579
# Name: count, dtype: int64

# %% [markdown]
# ## Labs
#
# ### Creatinine

# %%
print(ef.shape)
g = sns.boxplot('survived_icustay', 'lab_creatinine_min', data = ef)
# Out:
# (25512, 130)

# %%
print(ef.shape)
g = sns.boxplot('survived_icustay', 'lab_creatinine_max', data = ef)
# Out:
# (25512, 130)

# %% [markdown]
# ### Hematocrit

# %%
g = sns.boxplot('survived_icustay', 'lab_hematocrit_min', data = ef)

# %%
g = sns.boxplot('survived_icustay', 'lab_hematocrit_max', data = ef)

# %% [markdown]
# ### White Blood Cells

# %%
g = sns.boxplot('survived_icustay', 'lab_wbc_min', data = ef)

# %%
g = sns.boxplot('survived_icustay', 'lab_wbc_max', data = ef)

# %% [markdown]
# ## Questions
#
# ### Did presence/absence of an echo affect trends of fluid management? How did the echo affect the trend of fluid management?
#
# For the first question, we actually need to get information of all patients in the ICU who did not have an echo.

# %%
fluid_var = 'fluid_daily_input_ml'
to_plot = ef[[fluid_var + '_1', fluid_var + '_2', fluid_var + '_3']].unstack().reset_index()
to_plot.columns = ['day', 'row_id', fluid_var]

sns.boxplot(data = to_plot, x = 'day', y = fluid_var)

# %%
fluid_var = 'fluid_daily_balance_ml'
to_plot = ef[[fluid_var + '_1', fluid_var + '_2', fluid_var + '_3']].unstack().reset_index()
to_plot.columns = ['day', 'row_id', fluid_var]

sns.boxplot(data = to_plot, x = 'day', y = fluid_var)
